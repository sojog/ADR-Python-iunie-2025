# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.barplot(x=[10, 20, 30], y=[3, 5, 4])
sns.set_palette("pastel")
plt.show()

# %%
sns.lineplot (x=[10, 20, 30], y=[3, 5, 4])
plt.show()
