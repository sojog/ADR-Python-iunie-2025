# %% [markdown]
# # pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot( [1, 3, 4, 6])
plt.show()

# %%
plt.plot( [1, 3, 4, 6])
plt.ylabel("Valorile mele")
plt.xlabel("Indexi")
plt.show()

# %%
plt.scatter( [1, 3, 4, 6], [0, 1, 2, 3])
plt.ylabel("Valorile mele")
plt.xlabel("Indexi")
plt.show()

# %%
plt.plot( [1, 3, 4, 6], [2, 5, 7, 9])
plt.ylabel("Valorile mele")
plt.xlabel("Indexi")
plt.show()

# %%
array = np.arange(8).reshape((2, 4))
array
# Out:
# array([[0, 1, 2, 3],
#        [4, 5, 6, 7]])

# %%
plt.plot( array)
plt.ylabel("Valorile mele")
plt.xlabel("Indexi")
plt.show()

# %%
x =  np.random.randint(1, 100, 3)
y =  np.random.randint(1, 10, 3)
x, y
# Out:
# (array([13, 30, 82]), array([1, 1, 5]))

# %%
plt.pie(x)
plt.show()

# %%
plt.bar(x, y)
plt.show()
