# %%
import pandas as pd

# %%
df = pd.read_csv("retete.csv", index_col=0)
df.head()
# Out:
#                            name  prepTimeMinutes  cookTimeMinutes  servings  \
# index
# 0      Classic Margherita Pizza               20               15         4
# 1           Vegetarian Stir-Fry               15               20         3
# 2        Chocolate Chip Cookies               15               10        24
# 3         Chicken Alfredo Pasta               15               20         4
# 4           Mango Salsa Chicken               15               25         3
#
#        caloriesPerServing  reviewCount
# index
# 0                     300           98
# 1                     250           26
# 2                     150           13
# 3                     500           82
# 4                     380           63

# %%
df.dtypes
# Out:
# name                  object
# prepTimeMinutes        int64
# cookTimeMinutes        int64
# servings               int64
# caloriesPerServing     int64
# reviewCount            int64
# dtype: object

# %%
conditie = df["prepTimeMinutes"] < 15

df[conditie]
# Out:
#                             name  prepTimeMinutes  cookTimeMinutes  servings  \
# index
# 8                  Caprese Salad               10                0         2
# 21                   Mango Lassi               10                0         2
# 24     Blueberry Banana Smoothie               10                0         1
# 29          Brazilian Caipirinha                5                0         1
#
#        caloriesPerServing  reviewCount
# index
# 8                     200           82
# 21                    180           15
# 24                    220           30
# 29                    150           55

# %%
df[df["prepTimeMinutes"] < 15]
# Out:
#                             name  prepTimeMinutes  cookTimeMinutes  servings  \
# index
# 8                  Caprese Salad               10                0         2
# 21                   Mango Lassi               10                0         2
# 24     Blueberry Banana Smoothie               10                0         1
# 29          Brazilian Caipirinha                5                0         1
#
#        caloriesPerServing  reviewCount
# index
# 8                     200           82
# 21                    180           15
# 24                    220           30
# 29                    150           55

# %%
df["caloriesPerServing"].min()
# Out:
# np.int64(120)

# %%
conditie =    df["caloriesPerServing"] == df["caloriesPerServing"].min()
df[conditie]
# Out:
#                           name  prepTimeMinutes  cookTimeMinutes  servings  \
# index
# 6      Tomato Basil Bruschetta               15               10         6
#
#        caloriesPerServing  reviewCount
# index
# 6                     120           95

# %%
df.groupby("servings").agg(['count'])
# Out:
#           name prepTimeMinutes cookTimeMinutes caloriesPerServing reviewCount
#          count           count           count              count       count
# servings
# 1            2               2               2                  2           2
# 2            5               5               5                  5           5
# 3            4               4               4                  4           4
# 4           12              12              12                 12          12
# 5            1               1               1                  1           1
# 6            5               5               5                  5           5
# 24           1               1               1                  1           1

# %%
df[df["servings"] == 1]
# Out:
#                             name  prepTimeMinutes  cookTimeMinutes  servings  \
# index
# 24     Blueberry Banana Smoothie               10                0         1
# 29          Brazilian Caipirinha                5                0         1
#
#        caloriesPerServing  reviewCount
# index
# 24                    220           30
# 29                    150           55

# %%
grouped_df = df.groupby("servings").agg(['count']) 
grouped_df["name"]
# Out:
#           count
# servings
# 1             2
# 2             5
# 3             4
# 4            12
# 5             1
# 6             5
# 24            1

# %%
df.sort_values("caloriesPerServing").head(3)
# Out:
#                           name  prepTimeMinutes  cookTimeMinutes  servings  \
# index
# 6      Tomato Basil Bruschetta               15               10         6
# 29        Brazilian Caipirinha                5                0         1
# 2       Chocolate Chip Cookies               15               10        24
#
#        caloriesPerServing  reviewCount
# index
# 6                     120           95
# 29                    150           55
# 2                     150           13

# %%
df.sort_values(["caloriesPerServing", "servings"], ascending=(True, False)).head(2)
# Out:
#                           name  prepTimeMinutes  cookTimeMinutes  servings  \
# index
# 6      Tomato Basil Bruschetta               15               10         6
# 2       Chocolate Chip Cookies               15               10        24
#
#        caloriesPerServing  reviewCount
# index
# 6                     120           95
# 2                     150           13

# %%
df[ ["name", "servings", "prepTimeMinutes"]].head(2)
# Out:
#                            name  servings  prepTimeMinutes
# index
# 0      Classic Margherita Pizza         4               20
# 1           Vegetarian Stir-Fry         3               15

# %%
df.sort_values(["prepTimeMinutes", "servings"])
# Out:
#                                     name  prepTimeMinutes  cookTimeMinutes  \
# index
# 29                  Brazilian Caipirinha                5                0
# 24             Blueberry Banana Smoothie               10                0
# 8                          Caprese Salad               10                0
# 21                           Mango Lassi               10                0
# 28                 Lebanese Falafel Wrap               15               10
# 1                    Vegetarian Stir-Fry               15               20
# 4                    Mango Salsa Chicken               15               25
# 9                    Shrimp Scampi Pasta               15               20
# 3                  Chicken Alfredo Pasta               15               20
# 16              Moroccan Chickpea Tagine               15               30
# 25           Mexican Street Corn (Elote)               15               15
# ...

# %%
df [ df["prepTimeMinutes"].isin(range(20, 30))]
# Out:
#                              name  prepTimeMinutes  cookTimeMinutes  servings  \
# index
# 0        Classic Margherita Pizza               20               15         4
# 5       Quinoa Salad with Avocado               20               15         4
# 7      Beef and Broccoli Stir-Fry               20               15         4
# 11                 Chicken Karahi               20               30         4
# 12                     Aloo Keema               25               35         5
# 15            Japanese Ramen Soup               20               25         2
# 20               Thai Green Curry               20               30         4
# 23                 Turkish Kebabs               25               15         4
#
#        caloriesPerServing  reviewCount
# index
# 0                     300           98
# 5                     280           59
# 7                     380           58
# 11                    420           68
# 12                    380           53
# ...

# %%
new_df = df.head(1)

# %%
new_df
# Out:
#                            name  prepTimeMinutes  cookTimeMinutes  servings  \
# index
# 0      Classic Margherita Pizza               20               15         4
#
#        caloriesPerServing  reviewCount
# index
# 0                     300           98

# %%
new_df.to_json("reteta_unica.json")

# %%
dictionar_cu_o_reteta =  {
    "name": {
        "0" : "Mamaliga cu branga",
        "1" :  "Sarmale"
    },
    "prepTimeMinutes": {
        "0" : 10,
        "1" : 360
    },
    "cookTimeMinutes": {
        "0": 15,
        "1":720
    },
    "servings": {
        "0": 4,
        "1": 12
    },
    "caloriesPerServing": {
        "0": 100,
        "1":500
    },
    "reviewCount": {
        "0": 3421,
        "1":32131
    }
}

# %%
retete_adaugate_df = pd.DataFrame(dictionar_cu_o_reteta)
retete_adaugate_df
# Out:
#                  name  prepTimeMinutes  cookTimeMinutes  servings  \
# 0  Mamaliga cu branga               10               15         4
# 1             Sarmale              360              720        12
#
#    caloriesPerServing  reviewCount
# 0                 100         3421
# 1                 500        32131

# %%
merged_df = pd.concat([retete_adaugate_df, df]).reset_index(drop=True)
merged_df
# Out:
#                                  name  prepTimeMinutes  cookTimeMinutes  \
# 0                  Mamaliga cu branga               10               15
# 1                             Sarmale              360              720
# 2            Classic Margherita Pizza               20               15
# 3                 Vegetarian Stir-Fry               15               20
# 4              Chocolate Chip Cookies               15               10
# 5               Chicken Alfredo Pasta               15               20
# 6                 Mango Salsa Chicken               15               25
# 7           Quinoa Salad with Avocado               20               15
# 8             Tomato Basil Bruschetta               15               10
# 9          Beef and Broccoli Stir-Fry               20               15
# 10                      Caprese Salad               10                0
# 11                Shrimp Scampi Pasta               15               20
# ...

# %%
merged_df["cookTimeMinutes"].mean()
# Out:
# np.float64(41.25)

# %%
merged_df["cookTimeMinutes"].max(),merged_df["cookTimeMinutes"].min()
# Out:
# (np.int64(720), np.int64(0))

# %%
merged_df["totalCalories"] = merged_df["caloriesPerServing"] * merged_df["servings"]
merged_df.tail(2)
# Out:
#                      name  prepTimeMinutes  cookTimeMinutes  servings  \
# 30  Lebanese Falafel Wrap               15               10         2
# 31   Brazilian Caipirinha                5                0         1
#
#     caloriesPerServing  reviewCount  totalCalories
# 30                 400           84            800
# 31                 150           55            150

# %%
merged_df.describe()
# Out:
#        prepTimeMinutes  cookTimeMinutes   servings  caloriesPerServing  \
# count        32.000000        32.000000  32.000000           32.000000
# mean         31.718750        41.250000   4.593750          329.375000
# std          60.676421       124.479562   4.078736          129.389073
# min           5.000000         0.000000   1.000000          100.000000
# 25%          15.000000        13.750000   3.000000          220.000000
# 50%          20.000000        20.000000   4.000000          320.000000
# 75%          30.000000        30.000000   4.250000          420.000000
# max         360.000000       720.000000  24.000000          550.000000
#
#        reviewCount  totalCalories
# count     32.00000      32.000000
# mean    1159.40625    1463.125000
# std     5683.01526    1152.353657
# min        0.00000     150.000000
# 25%       29.00000     787.500000
# 50%       55.50000    1200.000000
# 75%       82.50000    1905.000000
# max    32131.00000    6000.000000

# %%
df.drop("name", axis=1).corr()
# Out:
#                     prepTimeMinutes  cookTimeMinutes  servings  \
# prepTimeMinutes            1.000000         0.606074  0.078667
# cookTimeMinutes            0.606074         1.000000  0.064561
# servings                   0.078667         0.064561  1.000000
# caloriesPerServing         0.398625         0.552441 -0.210713
# reviewCount                0.128718        -0.025471 -0.241883
#
#                     caloriesPerServing  reviewCount
# prepTimeMinutes               0.398625     0.128718
# cookTimeMinutes               0.552441    -0.025471
# servings                     -0.210713    -0.241883
# caloriesPerServing            1.000000    -0.018087
# reviewCount                  -0.018087     1.000000

# %%
corr = df.drop("name", axis=1).corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_697c0_row0_col0, #T_697c0_row1_col1, #T_697c0_row2_col2, #T_697c0_row3_col3, #T_697c0_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_697c0_row0_col1 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_697c0_row0_col2 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_697c0_row0_col3 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_697c0_row0_col4 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_697c0_row1_col0 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_697c0_row1_col2 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_697c0_row1_col3 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_697c0_row1_col4 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_697c0_row2_col0, #T_697c0_row2_col3, #T_697c0_row2_col4, #T_697c0_row4_col1, #T_697c0_row4_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_697c0_row2_col1 {
# ...

# %%
import seaborn as sns

corr = df.drop("name", axis=1).corr()

sns.heatmap(corr, annot=True)
# Out:
# <Axes: >
